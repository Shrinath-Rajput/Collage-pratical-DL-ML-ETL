# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input, Dense, Flatten, Reshape
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# Step 1: Load Dataset
(x_train, _), (x_test, _) = mnist.load_data()

# Normalize data
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# Reshape
x_train = x_train.reshape((len(x_train), 28, 28, 1))
x_test = x_test.reshape((len(x_test), 28, 28, 1))

# Step 2: Encoder
input_img = Input(shape=(28, 28, 1))

x = Flatten()(input_img)
x = Dense(128, activation='relu')(x)
x = Dense(64, activation='relu')(x)

# Bottleneck Layer
encoded = Dense(32, activation='relu')(x)

# Step 3: Decoder
x = Dense(64, activation='relu')(encoded)
x = Dense(128, activation='relu')(x)
x = Dense(784, activation='sigmoid')(x)

decoded = Reshape((28, 28, 1))(x)

# Step 4: Build Model
autoencoder = Model(input_img, decoded)

# Compile Model
autoencoder.compile(
    optimizer=Adam(),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# Model Summary
autoencoder.summary()

# Step 5: Train Model
history = autoencoder.fit(
    x_train,
    x_train,
    epochs=20,
    batch_size=256,
    shuffle=True,
    validation_data=(x_test, x_test)
)

# Step 6: Predict
decoded_imgs = autoencoder.predict(x_test)

# Step 7: Display Results
n = 10
plt.figure(figsize=(20, 4))

for i in range(n):
    
    # Original Image
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28), cmap='gray')
    plt.title("Original")
    plt.axis('off')

    # Reconstructed Image
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28), cmap='gray')
    plt.title("Reconstructed")
    plt.axis('off')

plt.show()

# Step 8: Plot Loss Graph

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'])
plt.show()
# Out:
# WARNING:tensorflow:From d:\e drive\Only_Project\Ann Classification project\.venv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 6s 1us/step
# WARNING:tensorflow:From d:\e drive\Only_Project\Ann Classification project\.venv\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 128)               100480
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dense_3 (Dense)             (None, 64)                2112
#
#  dense_4 (Dense)             (None, 128)               8320
#
#  dense_5 (Dense)             (None, 784)               101136
#
#  reshape (Reshape)           (None, 28, 28, 1)         0
#
# =================================================================
# Total params: 222384 (868.69 KB)
# Trainable params: 222384 (868.69 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# WARNING:tensorflow:From d:\e drive\Only_Project\Ann Classification project\.venv\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From d:\e drive\Only_Project\Ann Classification project\.venv\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 235/235 [==============================] - 7s 19ms/step - loss: 0.2351 - accuracy: 0.7864 - val_loss: 0.1624 - val_accuracy: 0.8029
# Epoch 2/20
# 235/235 [==============================] - 4s 18ms/step - loss: 0.1482 - accuracy: 0.8055 - val_loss: 0.1367 - val_accuracy: 0.8064
# Epoch 3/20
# 235/235 [==============================] - 5s 19ms/step - loss: 0.1321 - accuracy: 0.8084 - val_loss: 0.1250 - val_accuracy: 0.8079
# Epoch 4/20
# 235/235 [==============================] - 5s 21ms/step - loss: 0.1229 - accuracy: 0.8100 - val_loss: 0.1181 - val_accuracy: 0.8097
# Epoch 5/20
# 235/235 [==============================] - 5s 20ms/step - loss: 0.1169 - accuracy: 0.8109 - val_loss: 0.1135 - val_accuracy: 0.8108
# Epoch 6/20
# 235/235 [==============================] - 5s 20ms/step - loss: 0.1129 - accuracy: 0.8115 - val_loss: 0.1101 - val_accuracy: 0.8108
# Epoch 7/20
# 235/235 [==============================] - 4s 18ms/step - loss: 0.1101 - accuracy: 0.8119 - val_loss: 0.1074 - val_accuracy: 0.8114
# Epoch 8/20
# 235/235 [==============================] - 4s 18ms/step - loss: 0.1074 - accuracy: 0.8122 - val_loss: 0.1050 - val_accuracy: 0.8116
# Epoch 9/20
# 235/235 [==============================] - 4s 18ms/step - loss: 0.1050 - accuracy: 0.8125 - val_loss: 0.1027 - val_accuracy: 0.8116
# Epoch 10/20
# 235/235 [==============================] - 4s 18ms/step - loss: 0.1027 - accuracy: 0.8128 - val_loss: 0.1005 - val_accuracy: 0.8120
# Epoch 11/20
# 235/235 [==============================] - 4s 18ms/step - loss: 0.1009 - accuracy: 0.8130 - val_loss: 0.0991 - val_accuracy: 0.8125
# Epoch 12/20
# 235/235 [==============================] - 4s 17ms/step - loss: 0.0994 - accuracy: 0.8132 - val_loss: 0.0975 - val_accuracy: 0.8124
# Epoch 13/20
# 235/235 [==============================] - 4s 19ms/step - loss: 0.0981 - accuracy: 0.8134 - val_loss: 0.0962 - val_accuracy: 0.8126
# Epoch 14/20
# 235/235 [==============================] - 4s 18ms/step - loss: 0.0969 - accuracy: 0.8135 - val_loss: 0.0953 - val_accuracy: 0.8126
# Epoch 15/20
# 235/235 [==============================] - 4s 17ms/step - loss: 0.0960 - accuracy: 0.8136 - val_loss: 0.0946 - val_accuracy: 0.8127
# Epoch 16/20
# 235/235 [==============================] - 4s 17ms/step - loss: 0.0950 - accuracy: 0.8137 - val_loss: 0.0935 - val_accuracy: 0.8130
# Epoch 17/20
# 235/235 [==============================] - 4s 17ms/step - loss: 0.0941 - accuracy: 0.8138 - val_loss: 0.0930 - val_accuracy: 0.8129
# Epoch 18/20
# 235/235 [==============================] - 4s 18ms/step - loss: 0.0935 - accuracy: 0.8138 - val_loss: 0.0921 - val_accuracy: 0.8131
# Epoch 19/20
# 235/235 [==============================] - 4s 18ms/step - loss: 0.0928 - accuracy: 0.8139 - val_loss: 0.0914 - val_accuracy: 0.8130
# Epoch 20/20
# 235/235 [==============================] - 4s 19ms/step - loss: 0.0922 - accuracy: 0.8140 - val_loss: 0.0908 - val_accuracy: 0.8130
# 313/313 [==============================] - 1s 3ms/step
